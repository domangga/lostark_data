# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ------------------------------------- 165.9/165.9 kB 10.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------- ----------------------------- 2.0/7.8 MB 64.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.6/7.8 MB 59.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.7/7.8 MB 53.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 50.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    ---------------------------------------- 189.9/189.9 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------  2.2/2.2 MB 46.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 46.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
# ...

# %%
pip install pandas

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

headers = {
    'accept' : 'application/json',
    'authorization' : 'bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyIsImtpZCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyJ9.eyJpc3MiOiJodHRwczovL2x1ZHkuZ2FtZS5vbnN0b3ZlLmNvbSIsImF1ZCI6Imh0dHBzOi8vbHVkeS5nYW1lLm9uc3RvdmUuY29tL3Jlc291cmNlcyIsImNsaWVudF9pZCI6IjEwMDAwMDAwMDA1NDc0NTEifQ.o0boQSrtdwpoDQfiaXVhs2dnUoZF7TuCVcZhKlsbCwCIA2IB4_A7O5haHoSodYEUPxpDbesqw2Y9APBTfWJikiLUIkRFoOfZ48SwHowvoZeWMGShw5mGuVGvQ392FRJpgro5o9dSEj8VBC2JGcZhJSz0LB6txr9xK6PN8mt53gLPEjIbD580xGEqvAO-qTHjP7iPWR_Wku73-b79HYmaAd0zXIcLekyu2TAfSKw3dyiGqJjemDlElCDTDlKePuZvHHUqLNZz4B6mCkuoM1ZFstOu-IIYujuieLqzfkI3A0zfCyJw3h3RViFB0SUJMop078LHE3mvNN640Hc8DDkGuw'
}
 
url = 'https://developer-lostark.game.onstove.com/markets/items/65200505'
 
response = requests.get(url, headers=headers)
jsonObject = response.json()
 
print(response)

for list in jsonObject :
    print(list.get("Stats"))
# Out:
# <Response [200]>
# [{'Date': '2024-08-26', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-25', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-24', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-23', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-22', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-21', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-20', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-19', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-18', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-17', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-16', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-15', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-14', 'AvgPrice': 0.0, 'TradeCount': 0}, {'Date': '2024-08-13', 'AvgPrice': 0.0, 'TradeCount': 0}]
# ...

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

headers = {
    'accept' : 'application/json',
    'authorization' : 'bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyIsImtpZCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyJ9.eyJpc3MiOiJodHRwczovL2x1ZHkuZ2FtZS5vbnN0b3ZlLmNvbSIsImF1ZCI6Imh0dHBzOi8vbHVkeS5nYW1lLm9uc3RvdmUuY29tL3Jlc291cmNlcyIsImNsaWVudF9pZCI6IjEwMDAwMDAwMDA1NDc0NTEifQ.o0boQSrtdwpoDQfiaXVhs2dnUoZF7TuCVcZhKlsbCwCIA2IB4_A7O5haHoSodYEUPxpDbesqw2Y9APBTfWJikiLUIkRFoOfZ48SwHowvoZeWMGShw5mGuVGvQ392FRJpgro5o9dSEj8VBC2JGcZhJSz0LB6txr9xK6PN8mt53gLPEjIbD580xGEqvAO-qTHjP7iPWR_Wku73-b79HYmaAd0zXIcLekyu2TAfSKw3dyiGqJjemDlElCDTDlKePuZvHHUqLNZz4B6mCkuoM1ZFstOu-IIYujuieLqzfkI3A0zfCyJw3h3RViFB0SUJMop078LHE3mvNN640Hc8DDkGuw'
}
 
url = 'https://developer-lostark.game.onstove.com/markets/items/66102005'
 
response = requests.get(url, headers=headers)
jsonObject = response.json()
 
print(response)

for list in jsonObject :
    a=list.get("Stats")


dates = [entry['Date'] for entry in a]
avg_prices = [entry['AvgPrice'] for entry in a]
TradeCount = [entry['TradeCount'] for entry in a]


df = pd.DataFrame({'Date': dates, 'AvgPrice': avg_prices,'TradeCount':TradeCount})
plt.rc('font',family = 'Malgun Gothic')


plt.figure(figsize=(12, 6))
plt.scatter(df['Date'], df['AvgPrice'],c=TradeCount,cmap='rainbow',alpha=0.7)
plt.xticks(rotation=50)
plt.colorbar(label='거래 횟수 (단위 : 100만)')
plt.title("정제된 파괴강석 시세")
plt.ylabel('가격')
plt.xlabel('날짜')
plt.show()
# Out:
# <Response [200]>

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

headers = {
    'accept' : 'application/json',
    'authorization' : 'bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyIsImtpZCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyJ9.eyJpc3MiOiJodHRwczovL2x1ZHkuZ2FtZS5vbnN0b3ZlLmNvbSIsImF1ZCI6Imh0dHBzOi8vbHVkeS5nYW1lLm9uc3RvdmUuY29tL3Jlc291cmNlcyIsImNsaWVudF9pZCI6IjEwMDAwMDAwMDA1NDc0NTEifQ.o0boQSrtdwpoDQfiaXVhs2dnUoZF7TuCVcZhKlsbCwCIA2IB4_A7O5haHoSodYEUPxpDbesqw2Y9APBTfWJikiLUIkRFoOfZ48SwHowvoZeWMGShw5mGuVGvQ392FRJpgro5o9dSEj8VBC2JGcZhJSz0LB6txr9xK6PN8mt53gLPEjIbD580xGEqvAO-qTHjP7iPWR_Wku73-b79HYmaAd0zXIcLekyu2TAfSKw3dyiGqJjemDlElCDTDlKePuZvHHUqLNZz4B6mCkuoM1ZFstOu-IIYujuieLqzfkI3A0zfCyJw3h3RViFB0SUJMop078LHE3mvNN640Hc8DDkGuw'
}
 
url = 'https://developer-lostark.game.onstove.com/markets/items/6861011'
 
response = requests.get(url, headers=headers)
jsonObject = response.json()
 
print(response)

for list in jsonObject :
    a=list.get("Stats")


dates = [entry['Date'] for entry in a]
avg_prices = [entry['AvgPrice'] for entry in a]
TradeCount = [entry['TradeCount'] for entry in a]


df = pd.DataFrame({'Date': dates, 'AvgPrice': avg_prices,'TradeCount':TradeCount})
plt.rc('font',family = 'Malgun Gothic')


plt.figure(figsize=(12, 6))
plt.scatter(df['Date'], df['AvgPrice'],c=TradeCount,cmap='rainbow',alpha=0.7)
plt.xticks(rotation=50)
plt.colorbar(label='거래 횟수 (단위 : 100만)')
plt.title("최상급 오레하 융화제료 시세")
plt.ylabel('가격')
plt.xlabel('날짜')
plt.show()
# Out:
# <Response [200]>

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

headers = {
    'accept' : 'application/json',
    'authorization' : 'bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyIsImtpZCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyJ9.eyJpc3MiOiJodHRwczovL2x1ZHkuZ2FtZS5vbnN0b3ZlLmNvbSIsImF1ZCI6Imh0dHBzOi8vbHVkeS5nYW1lLm9uc3RvdmUuY29tL3Jlc291cmNlcyIsImNsaWVudF9pZCI6IjEwMDAwMDAwMDA1NDc0NTEifQ.o0boQSrtdwpoDQfiaXVhs2dnUoZF7TuCVcZhKlsbCwCIA2IB4_A7O5haHoSodYEUPxpDbesqw2Y9APBTfWJikiLUIkRFoOfZ48SwHowvoZeWMGShw5mGuVGvQ392FRJpgro5o9dSEj8VBC2JGcZhJSz0LB6txr9xK6PN8mt53gLPEjIbD580xGEqvAO-qTHjP7iPWR_Wku73-b79HYmaAd0zXIcLekyu2TAfSKw3dyiGqJjemDlElCDTDlKePuZvHHUqLNZz4B6mCkuoM1ZFstOu-IIYujuieLqzfkI3A0zfCyJw3h3RViFB0SUJMop078LHE3mvNN640Hc8DDkGuw'
}
 
url = 'https://developer-lostark.game.onstove.com/markets/items/6861011'
 
response = requests.get(url, headers=headers)
jsonObject = response.json()
 
print(response)

for list in jsonObject :
    a=list.get("Stats")


dates = [entry['Date'] for entry in a]
avg_prices = [entry['AvgPrice'] for entry in a]
TradeCount = [entry['TradeCount'] for entry in a]


df = pd.DataFrame({'Date': dates, 'AvgPrice': avg_prices,'TradeCount':TradeCount})
plt.rc('font',family = 'Malgun Gothic')


plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['AvgPrice'])
plt.xticks(rotation=50)

plt.title("최상급 오레하 융화제료 시세")
plt.ylabel('가격')
plt.xlabel('날짜')
plt.show()
# Out:
# <Response [200]>

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
headers = {
    'accept' : 'application/json',
    'authorization' : 'bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyIsImtpZCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyJ9.eyJpc3MiOiJodHRwczovL2x1ZHkuZ2FtZS5vbnN0b3ZlLmNvbSIsImF1ZCI6Imh0dHBzOi8vbHVkeS5nYW1lLm9uc3RvdmUuY29tL3Jlc291cmNlcyIsImNsaWVudF9pZCI6IjEwMDAwMDAwMDA1NDc0NTEifQ.o0boQSrtdwpoDQfiaXVhs2dnUoZF7TuCVcZhKlsbCwCIA2IB4_A7O5haHoSodYEUPxpDbesqw2Y9APBTfWJikiLUIkRFoOfZ48SwHowvoZeWMGShw5mGuVGvQ392FRJpgro5o9dSEj8VBC2JGcZhJSz0LB6txr9xK6PN8mt53gLPEjIbD580xGEqvAO-qTHjP7iPWR_Wku73-b79HYmaAd0zXIcLekyu2TAfSKw3dyiGqJjemDlElCDTDlKePuZvHHUqLNZz4B6mCkuoM1ZFstOu-IIYujuieLqzfkI3A0zfCyJw3h3RViFB0SUJMop078LHE3mvNN640Hc8DDkGuw'
}
 
url = 'https://developer-lostark.game.onstove.com/markets/items/6861011'
 
response = requests.get(url, headers=headers)
jsonObject = response.json()
 
print(response)

for list in jsonObject :
    a=list.get("Stats")


dates = [entry['Date'] for entry in a]
avg_prices = [entry['AvgPrice'] for entry in a]
TradeCount = [entry['TradeCount'] for entry in a]


df = pd.DataFrame({'Date': dates, 'AvgPrice': avg_prices,'TradeCount':TradeCount})
plt.rc('font',family = 'Malgun Gothic')


plt.figure(figsize=(12, 6))
sns.relplot(x='Date', y='AvgPrice', size='TradeCount',
            sizes=(100, 400), alpha=.5,
            height=6, data=df)

plt.xticks(rotation=50)

plt.title("최상급 오레하 융화제료 시세")
plt.ylabel('가격')
plt.xlabel('날짜')
plt.show()
# Out:
# <Response [200]>

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

headers = {
    'accept' : 'application/json',
    'authorization' : 'bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyIsImtpZCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyJ9.eyJpc3MiOiJodHRwczovL2x1ZHkuZ2FtZS5vbnN0b3ZlLmNvbSIsImF1ZCI6Imh0dHBzOi8vbHVkeS5nYW1lLm9uc3RvdmUuY29tL3Jlc291cmNlcyIsImNsaWVudF9pZCI6IjEwMDAwMDAwMDA1NDc0NTEifQ.o0boQSrtdwpoDQfiaXVhs2dnUoZF7TuCVcZhKlsbCwCIA2IB4_A7O5haHoSodYEUPxpDbesqw2Y9APBTfWJikiLUIkRFoOfZ48SwHowvoZeWMGShw5mGuVGvQ392FRJpgro5o9dSEj8VBC2JGcZhJSz0LB6txr9xK6PN8mt53gLPEjIbD580xGEqvAO-qTHjP7iPWR_Wku73-b79HYmaAd0zXIcLekyu2TAfSKw3dyiGqJjemDlElCDTDlKePuZvHHUqLNZz4B6mCkuoM1ZFstOu-IIYujuieLqzfkI3A0zfCyJw3h3RViFB0SUJMop078LHE3mvNN640Hc8DDkGuw'
}
 
url = 'https://developer-lostark.game.onstove.com/markets/items/65200505'
 
response = requests.get(url, headers=headers)
jsonObject = response.json()
 
print(response)

for list in jsonObject :
    a=list.get("Stats")


dates = [entry['Date'] for entry in a]
avg_prices = [entry['AvgPrice'] for entry in a]
TradeCount = [entry['TradeCount'] for entry in a]


df = pd.DataFrame({'Date': dates, 'AvgPrice': avg_prices,'TradeCount':TradeCount})
plt.rc('font',family = 'Malgun Gothic')


plt.figure(figsize=(12, 6))
plt.scatter(df['Date'], df['AvgPrice'],c=TradeCount,cmap='rainbow',alpha=0.7)
plt.xticks(rotation=50)
plt.colorbar(label='거래 횟수 (단위 : 10만)')
plt.title("원한 각인서 시세")
plt.ylabel('가격')
plt.xlabel('날짜')
plt.show()
# Out:
# <Response [200]>

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

headers = {
    'accept' : 'application/json',
    'authorization' : 'bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyIsImtpZCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyJ9.eyJpc3MiOiJodHRwczovL2x1ZHkuZ2FtZS5vbnN0b3ZlLmNvbSIsImF1ZCI6Imh0dHBzOi8vbHVkeS5nYW1lLm9uc3RvdmUuY29tL3Jlc291cmNlcyIsImNsaWVudF9pZCI6IjEwMDAwMDAwMDA1NDc0NTEifQ.o0boQSrtdwpoDQfiaXVhs2dnUoZF7TuCVcZhKlsbCwCIA2IB4_A7O5haHoSodYEUPxpDbesqw2Y9APBTfWJikiLUIkRFoOfZ48SwHowvoZeWMGShw5mGuVGvQ392FRJpgro5o9dSEj8VBC2JGcZhJSz0LB6txr9xK6PN8mt53gLPEjIbD580xGEqvAO-qTHjP7iPWR_Wku73-b79HYmaAd0zXIcLekyu2TAfSKw3dyiGqJjemDlElCDTDlKePuZvHHUqLNZz4B6mCkuoM1ZFstOu-IIYujuieLqzfkI3A0zfCyJw3h3RViFB0SUJMop078LHE3mvNN640Hc8DDkGuw'
}
 
url = 'https://developer-lostark.game.onstove.com/markets/items/6861011'
 
response = requests.get(url, headers=headers)
jsonObject = response.json()
 
print(response)

for list in jsonObject :
    print(list.get("Stats"))
# Out:
# <Response [200]>
# [{'Date': '2024-08-23', 'AvgPrice': 44.8, 'TradeCount': 1297886}, {'Date': '2024-08-22', 'AvgPrice': 44.7, 'TradeCount': 4399908}, {'Date': '2024-08-21', 'AvgPrice': 43.7, 'TradeCount': 4154708}, {'Date': '2024-08-20', 'AvgPrice': 43.8, 'TradeCount': 2704964}, {'Date': '2024-08-19', 'AvgPrice': 44.6, 'TradeCount': 3231604}, {'Date': '2024-08-18', 'AvgPrice': 45.2, 'TradeCount': 4493192}, {'Date': '2024-08-17', 'AvgPrice': 44.8, 'TradeCount': 4697614}, {'Date': '2024-08-16', 'AvgPrice': 44.6, 'TradeCount': 4255021}, {'Date': '2024-08-15', 'AvgPrice': 44.1, 'TradeCount': 5815074}, {'Date': '2024-08-14', 'AvgPrice': 43.1, 'TradeCount': 4134374}, {'Date': '2024-08-13', 'AvgPrice': 42.9, 'TradeCount': 2865251}, {'Date': '2024-08-12', 'AvgPrice': 43.9, 'TradeCount': 3440491}, {'Date': '2024-08-11', 'AvgPrice': 44.4, 'TradeCount': 4910023}, {'Date': '2024-08-10', 'AvgPrice': 44.6, 'TradeCount': 5101388}]

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    -------------------------------------- - 286.7/294.9 kB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 9.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

headers = {
    'accept' : 'application/json',
    'authorization' : 'bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyIsImtpZCI6IktYMk40TkRDSTJ5NTA5NWpjTWk5TllqY2lyZyJ9.eyJpc3MiOiJodHRwczovL2x1ZHkuZ2FtZS5vbnN0b3ZlLmNvbSIsImF1ZCI6Imh0dHBzOi8vbHVkeS5nYW1lLm9uc3RvdmUuY29tL3Jlc291cmNlcyIsImNsaWVudF9pZCI6IjEwMDAwMDAwMDA1NDc0NTEifQ.o0boQSrtdwpoDQfiaXVhs2dnUoZF7TuCVcZhKlsbCwCIA2IB4_A7O5haHoSodYEUPxpDbesqw2Y9APBTfWJikiLUIkRFoOfZ48SwHowvoZeWMGShw5mGuVGvQ392FRJpgro5o9dSEj8VBC2JGcZhJSz0LB6txr9xK6PN8mt53gLPEjIbD580xGEqvAO-qTHjP7iPWR_Wku73-b79HYmaAd0zXIcLekyu2TAfSKw3dyiGqJjemDlElCDTDlKePuZvHHUqLNZz4B6mCkuoM1ZFstOu-IIYujuieLqzfkI3A0zfCyJw3h3RViFB0SUJMop078LHE3mvNN640Hc8DDkGuw'
}
 
url = 'https://developer-lostark.game.onstove.com/markets/items/6861011'
 
response = requests.get(url, headers=headers)
jsonObject = response.json()
 
print(response)

for list in jsonObject :
    a=list.get("Stats")


dates = [entry['Date'] for entry in a]
avg_prices = [entry['AvgPrice'] for entry in a]
TradeCount = [entry['TradeCount'] for entry in a]


df = pd.DataFrame({'Date': dates, 'AvgPrice': avg_prices,'TradeCount':TradeCount})
plt.rc('font',family = 'Malgun Gothic')


plt.figure(figsize=(12, 6))
sns.histplot(data=df,x='Date',y='AvgPrice')
plt.xticks(rotation=50)
plt.colorbar(label='거래 횟수 단위(100만)')
plt.show()
# Out:
# <Response [200]>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 35
#      33 sns.histplot(data=df,x='Date',y='AvgPrice')
#      34 plt.xticks(rotation=50)
# ---> 35 plt.colorbar(label='거래 횟수 단위(100만)')
#      36 plt.show()
#
# File C:\python312\Lib\site-packages\matplotlib\pyplot.py:2512, in colorbar(mappable, cax, ax, **kwargs)
#    2510     mappable = gci()
#    2511     if mappable is None:
# -> 2512         raise RuntimeError('No mappable was found to use for colorbar '
#    2513                            'creation. First define a mappable such as '
#    2514                            'an image (with imshow) or a contour set ('
#    2515                            'with contourf).')
#    2516 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2517 return ret
#
# ...
